# %%
import pandas as pd
folder_path = "/home/heza7322/PycharmProjects/missing-value-handling-in-carts/data/results"

# %%
missing_set = 'all'
data_set = 'titanic'
old_df = pd.read_csv(f'{folder_path}/missing_{missing_set}/cv_results_{data_set}.csv',index_col = 0)
new_df = pd.read_csv(f'{folder_path}/missing_{missing_set}/cv_results_{data_set}_inc_mia.csv',index_col = 0)
old_df['TrinaryMia'] = new_df['TrinaryMia']
old_df
# Out:
#        Majority         MIA    Weighted     Trinary  TrinaryMia
# 0.0  327.910950  327.910950  327.910950  327.910950  327.910950
# 0.1  356.704388  361.207661  344.155923  342.696430  346.871039
# 0.2  416.506127  390.873440  364.334807  361.810130  355.239952
# 0.3  465.096349  402.725745  378.009670  371.202470  366.583942
# 0.4  454.074927  419.723621  405.960488  383.986543  376.123096
# 0.5  469.563883  478.536566  466.144805  403.923228  399.394073
# 0.6  468.432848  474.103973  469.255032  425.930109  432.171441
# 0.7  472.104704  473.577827  471.450358  437.978412  440.158393
# 0.8  479.614446  479.584170  477.169200  459.668607  470.535299
# 0.9  486.379107  480.863993  480.085910  483.176739  471.583618

# %%
old_df.plot()
# Out:
# <Axes: >

# %%
old_df.to_csv(f'{folder_path}/missing_{missing_set}/cv_results_{data_set}_new.csv')
